# %% [markdown]
# # Automated Evaluation Metric for Terminology Consistency in MT: Howto
#
# _Author: Kirill Semenov, Charles University, 2022, kir\[dоt]semenov[аt]yandex[dоt]ru_
#
# This is an example of the step-by-step application of the automated evaluation metric for terminology consistency in MT.

# %%
import os
import nltk
import re
import subprocess
import pandas as pd
from sklearn import preprocessing
from sklearn.metrics import f1_score

# %% [markdown]
# ## 1. Tokenization
#
# With this module, you can:
# 1. Tokenize separate text (`tokenize_file` method)
# 2. Tokenize the whole folder (`tokenize_folder` method)
#
# Currently, only Morphodita tokenizer is implemented. To run this tokenizer, you need to download the models to it from [here](https://ufal.mff.cuni.cz/morphodita#language_models) and specify the directory.

# %%
from tokenization import Tokenizer

# %%
tokenizer_cs = Tokenizer('morphodita', path_to_model='../agreement-corpus/tokenize_new.py')
tokenizer_en = Tokenizer('morphodita', path_to_model='../agreement-corpus/tokenize_new.py')

# %%
tokenizer_en.tokenize_file('./input_en/ALMAnaCH-Inria.txt', 'tokenized_en', language='English')
# Out:
# a
# ./input_en/ALMAnaCH-Inria.txt
# <class 'str'>
# ALMAnaCH-Inria.txt
# ALMAnaCH-Inria_tokenized.txt
# tokenized_en\ALMAnaCH-Inria_tokenized.txt
# 'tokenization for file ALMAnaCH-Inria_tokenized.txt done successfully'

# %%
tokenizer_cs.tokenize_folder('./raw_data/inputs_cs', './tokenized_data/inputs_cs', language='Czech')
# Out:
# au1tc.txt
# au2tc.txt
# au3tc.txt
# au4tc.txt
# au5tc.txt
# au6tc.txt
# au7tc.txt
# au8tc.txt
# au9tc.txt
# kn1tc.txt
# kn2tc.txt
# kn3tc.txt
# kn4tc.txt
# kn5tc.txt
# kn6tc.txt
# kn7tc.txt
# kn8tc.txt
# kn9tc.txt
# na1tc.txt
# na2tc.txt
# na3tc.txt
# na4tc.txt
# na5tc.txt
# na6tc.txt
# na7tc.txt
# pn1tc.txt
# pn2tc.txt
# pn3tc.txt
# pn4tc.txt
# pn5tc.txt
# robot.txt
# SLA.txt
# sublease.txt
# 'tokenization for folder ./raw_data/inputs_cs done successfully'

# %%
outputs_2021_folders = os.listdir('./raw_data/outputs_en_2021/')
outputs_2022_folders = os.listdir('./raw_data/outputs_en_2022/')

# %%
for output_2021_folder in outputs_2021_folders:
    i_folder = './raw_data/outputs_en_2021/' + output_2021_folder
    o_folder = './tokenized_data/outputs_en_2021/' + output_2021_folder
    # create a folder
    os.mkdir(o_folder)
    # make tokenization
    tokenizer_en.tokenize_folder(i_folder, o_folder, language='english')
# Out:
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer2018.txt
# Facebook-AI.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt

# %%
for output_2022_folder in outputs_2022_folders:
    i_folder = './raw_data/outputs_en_2022/' + output_2022_folder
    o_folder = './tokenized_data/outputs_en_2022/' + output_2022_folder
    # create a folder
    os.mkdir(o_folder)
    # make tokenization
    tokenizer_en.tokenize_folder(i_folder, o_folder, language='english')
# Out:
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt
# ALMAnaCH-Inria.txt
# CUNI-DocTransformer.txt
# CUNI-Transformer.txt
# JDExploreAcademy.txt
# Lan-Bridge.txt
# Online-A.txt
# Online-B.txt
# Online-G.txt
# Online-W.txt
# Online-Y.txt
# SHOPLINE-PL.txt

# %% [markdown]
# ## 2. Alignment
#
# Currently, `fast-align` algorithm is applied, and the code is adjusted only to this approach. You can consider using another automatic alignment approaches (such as `MGIZA++`).
#
# **TIP:** the unsupervised aligners work better if applied to big collections of parallel sentences (>100K sentence pairs). So  consider:
# 1. merging your files into one (but remember to split them after!): this is what I did there and obtained at least 4K sentence pairs per system;
# 2. adding some bigger parallel corpus to your data.

# %%
from alignment import Aligner

# %%
fast_align_dir = fast_align_path = os.path.join('/mnt', 'c', 'Users', 'Kirill Semenov',
                               'multiling_nlp_for_me', 'pos_tagging', 'fast_align', 'build')

fast_align_dir = fast_align_path = os.path.join('/mnt/c/Users/Kirill Semenov/multiling_nlp_for_me/pos_tagging/fast_align/build')

# %%
i = './raw_data/inputs_cs/au1tc.txt'
o = './raw_data/outputs_en_2021/au1tc/CUNI-DocTransformer.txt'

# %%
aligner = Aligner()

# %%
os.listdir('./tokenized_data/outputs_en_2021/au1tc')
# Out:
# ['CUNI-DocTransformer_tokenized.txt',
#  'CUNI-Transformer2018_tokenized.txt',
#  'Facebook-AI_tokenized.txt',
#  'Online-A_tokenized.txt',
#  'Online-B_tokenized.txt',
#  'Online-G_tokenized.txt',
#  'Online-W_tokenized.txt',
#  'Online-Y_tokenized.txt']

# %%
import re
input_folder = './tokenized_data/inputs_cs/'
input_files = os.listdir(input_folder)
output_folder = './tokenized_data/outputs_en_2022/'
for i in input_files:
    i_strip = re.sub('_tokenized.txt', '', i)
    o_list = os.listdir(f'{output_folder}{i_strip}')
    for output_file in o_list:
        #o_strip = re.sub('_tokenized.txt', '', output_file)
        i_path = f'{input_folder}{i}'
        o_path = f'{output_folder}{i_strip}/{output_file}'
        aligner.create_bitext(i_path, o_path, './alignments/2022/bitexts/')
# Out:
# ./tokenized_data/inputs_cs/au1tc_tokenized.txt
# au1tc.txt
# ./tokenized_data/outputs_en_2022/au1tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/au1tc_tokenized.txt
# au1tc.txt
# ./tokenized_data/outputs_en_2022/au1tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/au1tc_tokenized.txt
# au1tc.txt
# ./tokenized_data/outputs_en_2022/au1tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/au1tc_tokenized.txt
# au1tc.txt
# ./tokenized_data/outputs_en_2022/au1tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/au1tc_tokenized.txt
# au1tc.txt
# ./tokenized_data/outputs_en_2022/au1tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/au1tc_tokenized.txt
# au1tc.txt
# ./tokenized_data/outputs_en_2022/au1tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/au1tc_tokenized.txt
# au1tc.txt
# ./tokenized_data/outputs_en_2022/au1tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/au1tc_tokenized.txt
# au1tc.txt
# ./tokenized_data/outputs_en_2022/au1tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/au1tc_tokenized.txt
# au1tc.txt
# ./tokenized_data/outputs_en_2022/au1tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/au1tc_tokenized.txt
# au1tc.txt
# ./tokenized_data/outputs_en_2022/au1tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/au1tc_tokenized.txt
# au1tc.txt
# ./tokenized_data/outputs_en_2022/au1tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/au2tc_tokenized.txt
# au2tc.txt
# ./tokenized_data/outputs_en_2022/au2tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/au2tc_tokenized.txt
# au2tc.txt
# ./tokenized_data/outputs_en_2022/au2tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/au2tc_tokenized.txt
# au2tc.txt
# ./tokenized_data/outputs_en_2022/au2tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/au2tc_tokenized.txt
# au2tc.txt
# ./tokenized_data/outputs_en_2022/au2tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/au2tc_tokenized.txt
# au2tc.txt
# ./tokenized_data/outputs_en_2022/au2tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/au2tc_tokenized.txt
# au2tc.txt
# ./tokenized_data/outputs_en_2022/au2tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/au2tc_tokenized.txt
# au2tc.txt
# ./tokenized_data/outputs_en_2022/au2tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/au2tc_tokenized.txt
# au2tc.txt
# ./tokenized_data/outputs_en_2022/au2tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/au2tc_tokenized.txt
# au2tc.txt
# ./tokenized_data/outputs_en_2022/au2tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/au2tc_tokenized.txt
# au2tc.txt
# ./tokenized_data/outputs_en_2022/au2tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/au2tc_tokenized.txt
# au2tc.txt
# ./tokenized_data/outputs_en_2022/au2tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/au3tc_tokenized.txt
# au3tc.txt
# ./tokenized_data/outputs_en_2022/au3tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/au3tc_tokenized.txt
# au3tc.txt
# ./tokenized_data/outputs_en_2022/au3tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/au3tc_tokenized.txt
# au3tc.txt
# ./tokenized_data/outputs_en_2022/au3tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/au3tc_tokenized.txt
# au3tc.txt
# ./tokenized_data/outputs_en_2022/au3tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/au3tc_tokenized.txt
# au3tc.txt
# ./tokenized_data/outputs_en_2022/au3tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/au3tc_tokenized.txt
# au3tc.txt
# ./tokenized_data/outputs_en_2022/au3tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/au3tc_tokenized.txt
# au3tc.txt
# ./tokenized_data/outputs_en_2022/au3tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/au3tc_tokenized.txt
# au3tc.txt
# ./tokenized_data/outputs_en_2022/au3tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/au3tc_tokenized.txt
# au3tc.txt
# ./tokenized_data/outputs_en_2022/au3tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/au3tc_tokenized.txt
# au3tc.txt
# ./tokenized_data/outputs_en_2022/au3tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/au3tc_tokenized.txt
# au3tc.txt
# ./tokenized_data/outputs_en_2022/au3tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/au4tc_tokenized.txt
# au4tc.txt
# ./tokenized_data/outputs_en_2022/au4tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/au4tc_tokenized.txt
# au4tc.txt
# ./tokenized_data/outputs_en_2022/au4tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/au4tc_tokenized.txt
# au4tc.txt
# ./tokenized_data/outputs_en_2022/au4tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/au4tc_tokenized.txt
# au4tc.txt
# ./tokenized_data/outputs_en_2022/au4tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/au4tc_tokenized.txt
# au4tc.txt
# ./tokenized_data/outputs_en_2022/au4tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/au4tc_tokenized.txt
# au4tc.txt
# ./tokenized_data/outputs_en_2022/au4tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/au4tc_tokenized.txt
# au4tc.txt
# ./tokenized_data/outputs_en_2022/au4tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/au4tc_tokenized.txt
# au4tc.txt
# ./tokenized_data/outputs_en_2022/au4tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/au4tc_tokenized.txt
# au4tc.txt
# ./tokenized_data/outputs_en_2022/au4tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/au4tc_tokenized.txt
# au4tc.txt
# ./tokenized_data/outputs_en_2022/au4tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/au4tc_tokenized.txt
# au4tc.txt
# ./tokenized_data/outputs_en_2022/au4tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/au5tc_tokenized.txt
# au5tc.txt
# ./tokenized_data/outputs_en_2022/au5tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/au5tc_tokenized.txt
# au5tc.txt
# ./tokenized_data/outputs_en_2022/au5tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/au5tc_tokenized.txt
# au5tc.txt
# ./tokenized_data/outputs_en_2022/au5tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/au5tc_tokenized.txt
# au5tc.txt
# ./tokenized_data/outputs_en_2022/au5tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/au5tc_tokenized.txt
# au5tc.txt
# ./tokenized_data/outputs_en_2022/au5tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/au5tc_tokenized.txt
# au5tc.txt
# ./tokenized_data/outputs_en_2022/au5tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/au5tc_tokenized.txt
# au5tc.txt
# ./tokenized_data/outputs_en_2022/au5tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/au5tc_tokenized.txt
# au5tc.txt
# ./tokenized_data/outputs_en_2022/au5tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/au5tc_tokenized.txt
# au5tc.txt
# ./tokenized_data/outputs_en_2022/au5tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/au5tc_tokenized.txt
# au5tc.txt
# ./tokenized_data/outputs_en_2022/au5tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/au5tc_tokenized.txt
# au5tc.txt
# ./tokenized_data/outputs_en_2022/au5tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/au6tc_tokenized.txt
# au6tc.txt
# ./tokenized_data/outputs_en_2022/au6tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/au6tc_tokenized.txt
# au6tc.txt
# ./tokenized_data/outputs_en_2022/au6tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/au6tc_tokenized.txt
# au6tc.txt
# ./tokenized_data/outputs_en_2022/au6tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/au6tc_tokenized.txt
# au6tc.txt
# ./tokenized_data/outputs_en_2022/au6tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/au6tc_tokenized.txt
# au6tc.txt
# ./tokenized_data/outputs_en_2022/au6tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/au6tc_tokenized.txt
# au6tc.txt
# ./tokenized_data/outputs_en_2022/au6tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/au6tc_tokenized.txt
# au6tc.txt
# ./tokenized_data/outputs_en_2022/au6tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/au6tc_tokenized.txt
# au6tc.txt
# ./tokenized_data/outputs_en_2022/au6tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/au6tc_tokenized.txt
# au6tc.txt
# ./tokenized_data/outputs_en_2022/au6tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/au6tc_tokenized.txt
# au6tc.txt
# ./tokenized_data/outputs_en_2022/au6tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/au6tc_tokenized.txt
# au6tc.txt
# ./tokenized_data/outputs_en_2022/au6tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/au7tc_tokenized.txt
# au7tc.txt
# ./tokenized_data/outputs_en_2022/au7tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/au7tc_tokenized.txt
# au7tc.txt
# ./tokenized_data/outputs_en_2022/au7tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/au7tc_tokenized.txt
# au7tc.txt
# ./tokenized_data/outputs_en_2022/au7tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/au7tc_tokenized.txt
# au7tc.txt
# ./tokenized_data/outputs_en_2022/au7tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/au7tc_tokenized.txt
# au7tc.txt
# ./tokenized_data/outputs_en_2022/au7tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/au7tc_tokenized.txt
# au7tc.txt
# ./tokenized_data/outputs_en_2022/au7tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/au7tc_tokenized.txt
# au7tc.txt
# ./tokenized_data/outputs_en_2022/au7tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/au7tc_tokenized.txt
# au7tc.txt
# ./tokenized_data/outputs_en_2022/au7tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/au7tc_tokenized.txt
# au7tc.txt
# ./tokenized_data/outputs_en_2022/au7tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/au7tc_tokenized.txt
# au7tc.txt
# ./tokenized_data/outputs_en_2022/au7tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/au7tc_tokenized.txt
# au7tc.txt
# ./tokenized_data/outputs_en_2022/au7tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/au8tc_tokenized.txt
# au8tc.txt
# ./tokenized_data/outputs_en_2022/au8tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/au8tc_tokenized.txt
# au8tc.txt
# ./tokenized_data/outputs_en_2022/au8tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/au8tc_tokenized.txt
# au8tc.txt
# ./tokenized_data/outputs_en_2022/au8tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/au8tc_tokenized.txt
# au8tc.txt
# ./tokenized_data/outputs_en_2022/au8tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/au8tc_tokenized.txt
# au8tc.txt
# ./tokenized_data/outputs_en_2022/au8tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/au8tc_tokenized.txt
# au8tc.txt
# ./tokenized_data/outputs_en_2022/au8tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/au8tc_tokenized.txt
# au8tc.txt
# ./tokenized_data/outputs_en_2022/au8tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/au8tc_tokenized.txt
# au8tc.txt
# ./tokenized_data/outputs_en_2022/au8tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/au8tc_tokenized.txt
# au8tc.txt
# ./tokenized_data/outputs_en_2022/au8tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/au8tc_tokenized.txt
# au8tc.txt
# ./tokenized_data/outputs_en_2022/au8tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/au8tc_tokenized.txt
# au8tc.txt
# ./tokenized_data/outputs_en_2022/au8tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/au9tc_tokenized.txt
# au9tc.txt
# ./tokenized_data/outputs_en_2022/au9tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/au9tc_tokenized.txt
# au9tc.txt
# ./tokenized_data/outputs_en_2022/au9tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/au9tc_tokenized.txt
# au9tc.txt
# ./tokenized_data/outputs_en_2022/au9tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/au9tc_tokenized.txt
# au9tc.txt
# ./tokenized_data/outputs_en_2022/au9tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/au9tc_tokenized.txt
# au9tc.txt
# ./tokenized_data/outputs_en_2022/au9tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/au9tc_tokenized.txt
# au9tc.txt
# ./tokenized_data/outputs_en_2022/au9tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/au9tc_tokenized.txt
# au9tc.txt
# ./tokenized_data/outputs_en_2022/au9tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/au9tc_tokenized.txt
# au9tc.txt
# ./tokenized_data/outputs_en_2022/au9tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/au9tc_tokenized.txt
# au9tc.txt
# ./tokenized_data/outputs_en_2022/au9tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/au9tc_tokenized.txt
# au9tc.txt
# ./tokenized_data/outputs_en_2022/au9tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/au9tc_tokenized.txt
# au9tc.txt
# ./tokenized_data/outputs_en_2022/au9tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/kn1tc_tokenized.txt
# kn1tc.txt
# ./tokenized_data/outputs_en_2022/kn1tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/kn1tc_tokenized.txt
# kn1tc.txt
# ./tokenized_data/outputs_en_2022/kn1tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/kn1tc_tokenized.txt
# kn1tc.txt
# ./tokenized_data/outputs_en_2022/kn1tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/kn1tc_tokenized.txt
# kn1tc.txt
# ./tokenized_data/outputs_en_2022/kn1tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/kn1tc_tokenized.txt
# kn1tc.txt
# ./tokenized_data/outputs_en_2022/kn1tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/kn1tc_tokenized.txt
# kn1tc.txt
# ./tokenized_data/outputs_en_2022/kn1tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/kn1tc_tokenized.txt
# kn1tc.txt
# ./tokenized_data/outputs_en_2022/kn1tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/kn1tc_tokenized.txt
# kn1tc.txt
# ./tokenized_data/outputs_en_2022/kn1tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/kn1tc_tokenized.txt
# kn1tc.txt
# ./tokenized_data/outputs_en_2022/kn1tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/kn1tc_tokenized.txt
# kn1tc.txt
# ./tokenized_data/outputs_en_2022/kn1tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/kn1tc_tokenized.txt
# kn1tc.txt
# ./tokenized_data/outputs_en_2022/kn1tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/kn2tc_tokenized.txt
# kn2tc.txt
# ./tokenized_data/outputs_en_2022/kn2tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/kn2tc_tokenized.txt
# kn2tc.txt
# ./tokenized_data/outputs_en_2022/kn2tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/kn2tc_tokenized.txt
# kn2tc.txt
# ./tokenized_data/outputs_en_2022/kn2tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/kn2tc_tokenized.txt
# kn2tc.txt
# ./tokenized_data/outputs_en_2022/kn2tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/kn2tc_tokenized.txt
# kn2tc.txt
# ./tokenized_data/outputs_en_2022/kn2tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/kn2tc_tokenized.txt
# kn2tc.txt
# ./tokenized_data/outputs_en_2022/kn2tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/kn2tc_tokenized.txt
# kn2tc.txt
# ./tokenized_data/outputs_en_2022/kn2tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/kn2tc_tokenized.txt
# kn2tc.txt
# ./tokenized_data/outputs_en_2022/kn2tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/kn2tc_tokenized.txt
# kn2tc.txt
# ./tokenized_data/outputs_en_2022/kn2tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/kn2tc_tokenized.txt
# kn2tc.txt
# ./tokenized_data/outputs_en_2022/kn2tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/kn2tc_tokenized.txt
# kn2tc.txt
# ./tokenized_data/outputs_en_2022/kn2tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/kn3tc_tokenized.txt
# kn3tc.txt
# ./tokenized_data/outputs_en_2022/kn3tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/kn3tc_tokenized.txt
# kn3tc.txt
# ./tokenized_data/outputs_en_2022/kn3tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/kn3tc_tokenized.txt
# kn3tc.txt
# ./tokenized_data/outputs_en_2022/kn3tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/kn3tc_tokenized.txt
# kn3tc.txt
# ./tokenized_data/outputs_en_2022/kn3tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/kn3tc_tokenized.txt
# kn3tc.txt
# ./tokenized_data/outputs_en_2022/kn3tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/kn3tc_tokenized.txt
# kn3tc.txt
# ./tokenized_data/outputs_en_2022/kn3tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/kn3tc_tokenized.txt
# kn3tc.txt
# ./tokenized_data/outputs_en_2022/kn3tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/kn3tc_tokenized.txt
# kn3tc.txt
# ./tokenized_data/outputs_en_2022/kn3tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/kn3tc_tokenized.txt
# kn3tc.txt
# ./tokenized_data/outputs_en_2022/kn3tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/kn3tc_tokenized.txt
# kn3tc.txt
# ./tokenized_data/outputs_en_2022/kn3tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/kn3tc_tokenized.txt
# kn3tc.txt
# ./tokenized_data/outputs_en_2022/kn3tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/kn4tc_tokenized.txt
# kn4tc.txt
# ./tokenized_data/outputs_en_2022/kn4tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/kn4tc_tokenized.txt
# kn4tc.txt
# ./tokenized_data/outputs_en_2022/kn4tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/kn4tc_tokenized.txt
# kn4tc.txt
# ./tokenized_data/outputs_en_2022/kn4tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/kn4tc_tokenized.txt
# kn4tc.txt
# ./tokenized_data/outputs_en_2022/kn4tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/kn4tc_tokenized.txt
# kn4tc.txt
# ./tokenized_data/outputs_en_2022/kn4tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/kn4tc_tokenized.txt
# kn4tc.txt
# ./tokenized_data/outputs_en_2022/kn4tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/kn4tc_tokenized.txt
# kn4tc.txt
# ./tokenized_data/outputs_en_2022/kn4tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/kn4tc_tokenized.txt
# kn4tc.txt
# ./tokenized_data/outputs_en_2022/kn4tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/kn4tc_tokenized.txt
# kn4tc.txt
# ./tokenized_data/outputs_en_2022/kn4tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/kn4tc_tokenized.txt
# kn4tc.txt
# ./tokenized_data/outputs_en_2022/kn4tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/kn4tc_tokenized.txt
# kn4tc.txt
# ./tokenized_data/outputs_en_2022/kn4tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/kn5tc_tokenized.txt
# kn5tc.txt
# ./tokenized_data/outputs_en_2022/kn5tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/kn5tc_tokenized.txt
# kn5tc.txt
# ./tokenized_data/outputs_en_2022/kn5tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/kn5tc_tokenized.txt
# kn5tc.txt
# ./tokenized_data/outputs_en_2022/kn5tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/kn5tc_tokenized.txt
# kn5tc.txt
# ./tokenized_data/outputs_en_2022/kn5tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/kn5tc_tokenized.txt
# kn5tc.txt
# ./tokenized_data/outputs_en_2022/kn5tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/kn5tc_tokenized.txt
# kn5tc.txt
# ./tokenized_data/outputs_en_2022/kn5tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/kn5tc_tokenized.txt
# kn5tc.txt
# ./tokenized_data/outputs_en_2022/kn5tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/kn5tc_tokenized.txt
# kn5tc.txt
# ./tokenized_data/outputs_en_2022/kn5tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/kn5tc_tokenized.txt
# kn5tc.txt
# ./tokenized_data/outputs_en_2022/kn5tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/kn5tc_tokenized.txt
# kn5tc.txt
# ./tokenized_data/outputs_en_2022/kn5tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/kn5tc_tokenized.txt
# kn5tc.txt
# ./tokenized_data/outputs_en_2022/kn5tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/kn6tc_tokenized.txt
# kn6tc.txt
# ./tokenized_data/outputs_en_2022/kn6tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/kn6tc_tokenized.txt
# kn6tc.txt
# ./tokenized_data/outputs_en_2022/kn6tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/kn6tc_tokenized.txt
# kn6tc.txt
# ./tokenized_data/outputs_en_2022/kn6tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/kn6tc_tokenized.txt
# kn6tc.txt
# ./tokenized_data/outputs_en_2022/kn6tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/kn6tc_tokenized.txt
# kn6tc.txt
# ./tokenized_data/outputs_en_2022/kn6tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/kn6tc_tokenized.txt
# kn6tc.txt
# ./tokenized_data/outputs_en_2022/kn6tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/kn6tc_tokenized.txt
# kn6tc.txt
# ./tokenized_data/outputs_en_2022/kn6tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/kn6tc_tokenized.txt
# kn6tc.txt
# ./tokenized_data/outputs_en_2022/kn6tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/kn6tc_tokenized.txt
# kn6tc.txt
# ./tokenized_data/outputs_en_2022/kn6tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/kn6tc_tokenized.txt
# kn6tc.txt
# ./tokenized_data/outputs_en_2022/kn6tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/kn6tc_tokenized.txt
# kn6tc.txt
# ./tokenized_data/outputs_en_2022/kn6tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/kn7tc_tokenized.txt
# kn7tc.txt
# ./tokenized_data/outputs_en_2022/kn7tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/kn7tc_tokenized.txt
# kn7tc.txt
# ./tokenized_data/outputs_en_2022/kn7tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/kn7tc_tokenized.txt
# kn7tc.txt
# ./tokenized_data/outputs_en_2022/kn7tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/kn7tc_tokenized.txt
# kn7tc.txt
# ./tokenized_data/outputs_en_2022/kn7tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/kn7tc_tokenized.txt
# kn7tc.txt
# ./tokenized_data/outputs_en_2022/kn7tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/kn7tc_tokenized.txt
# kn7tc.txt
# ./tokenized_data/outputs_en_2022/kn7tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/kn7tc_tokenized.txt
# kn7tc.txt
# ./tokenized_data/outputs_en_2022/kn7tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/kn7tc_tokenized.txt
# kn7tc.txt
# ./tokenized_data/outputs_en_2022/kn7tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/kn7tc_tokenized.txt
# kn7tc.txt
# ./tokenized_data/outputs_en_2022/kn7tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/kn7tc_tokenized.txt
# kn7tc.txt
# ./tokenized_data/outputs_en_2022/kn7tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/kn7tc_tokenized.txt
# kn7tc.txt
# ./tokenized_data/outputs_en_2022/kn7tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/kn8tc_tokenized.txt
# kn8tc.txt
# ./tokenized_data/outputs_en_2022/kn8tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/kn8tc_tokenized.txt
# kn8tc.txt
# ./tokenized_data/outputs_en_2022/kn8tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/kn8tc_tokenized.txt
# kn8tc.txt
# ./tokenized_data/outputs_en_2022/kn8tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/kn8tc_tokenized.txt
# kn8tc.txt
# ./tokenized_data/outputs_en_2022/kn8tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/kn8tc_tokenized.txt
# kn8tc.txt
# ./tokenized_data/outputs_en_2022/kn8tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/kn8tc_tokenized.txt
# kn8tc.txt
# ./tokenized_data/outputs_en_2022/kn8tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/kn8tc_tokenized.txt
# kn8tc.txt
# ./tokenized_data/outputs_en_2022/kn8tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/kn8tc_tokenized.txt
# kn8tc.txt
# ./tokenized_data/outputs_en_2022/kn8tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/kn8tc_tokenized.txt
# kn8tc.txt
# ./tokenized_data/outputs_en_2022/kn8tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/kn8tc_tokenized.txt
# kn8tc.txt
# ./tokenized_data/outputs_en_2022/kn8tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/kn8tc_tokenized.txt
# kn8tc.txt
# ./tokenized_data/outputs_en_2022/kn8tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/kn9tc_tokenized.txt
# kn9tc.txt
# ./tokenized_data/outputs_en_2022/kn9tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/kn9tc_tokenized.txt
# kn9tc.txt
# ./tokenized_data/outputs_en_2022/kn9tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/kn9tc_tokenized.txt
# kn9tc.txt
# ./tokenized_data/outputs_en_2022/kn9tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/kn9tc_tokenized.txt
# kn9tc.txt
# ./tokenized_data/outputs_en_2022/kn9tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/kn9tc_tokenized.txt
# kn9tc.txt
# ./tokenized_data/outputs_en_2022/kn9tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/kn9tc_tokenized.txt
# kn9tc.txt
# ./tokenized_data/outputs_en_2022/kn9tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/kn9tc_tokenized.txt
# kn9tc.txt
# ./tokenized_data/outputs_en_2022/kn9tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/kn9tc_tokenized.txt
# kn9tc.txt
# ./tokenized_data/outputs_en_2022/kn9tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/kn9tc_tokenized.txt
# kn9tc.txt
# ./tokenized_data/outputs_en_2022/kn9tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/kn9tc_tokenized.txt
# kn9tc.txt
# ./tokenized_data/outputs_en_2022/kn9tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/kn9tc_tokenized.txt
# kn9tc.txt
# ./tokenized_data/outputs_en_2022/kn9tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/na1tc_tokenized.txt
# na1tc.txt
# ./tokenized_data/outputs_en_2022/na1tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/na1tc_tokenized.txt
# na1tc.txt
# ./tokenized_data/outputs_en_2022/na1tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/na1tc_tokenized.txt
# na1tc.txt
# ./tokenized_data/outputs_en_2022/na1tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/na1tc_tokenized.txt
# na1tc.txt
# ./tokenized_data/outputs_en_2022/na1tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/na1tc_tokenized.txt
# na1tc.txt
# ./tokenized_data/outputs_en_2022/na1tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/na1tc_tokenized.txt
# na1tc.txt
# ./tokenized_data/outputs_en_2022/na1tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/na1tc_tokenized.txt
# na1tc.txt
# ./tokenized_data/outputs_en_2022/na1tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/na1tc_tokenized.txt
# na1tc.txt
# ./tokenized_data/outputs_en_2022/na1tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/na1tc_tokenized.txt
# na1tc.txt
# ./tokenized_data/outputs_en_2022/na1tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/na1tc_tokenized.txt
# na1tc.txt
# ./tokenized_data/outputs_en_2022/na1tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/na1tc_tokenized.txt
# na1tc.txt
# ./tokenized_data/outputs_en_2022/na1tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/na2tc_tokenized.txt
# na2tc.txt
# ./tokenized_data/outputs_en_2022/na2tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/na2tc_tokenized.txt
# na2tc.txt
# ./tokenized_data/outputs_en_2022/na2tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/na2tc_tokenized.txt
# na2tc.txt
# ./tokenized_data/outputs_en_2022/na2tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/na2tc_tokenized.txt
# na2tc.txt
# ./tokenized_data/outputs_en_2022/na2tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/na2tc_tokenized.txt
# na2tc.txt
# ./tokenized_data/outputs_en_2022/na2tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/na2tc_tokenized.txt
# na2tc.txt
# ./tokenized_data/outputs_en_2022/na2tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/na2tc_tokenized.txt
# na2tc.txt
# ./tokenized_data/outputs_en_2022/na2tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/na2tc_tokenized.txt
# na2tc.txt
# ./tokenized_data/outputs_en_2022/na2tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/na2tc_tokenized.txt
# na2tc.txt
# ./tokenized_data/outputs_en_2022/na2tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/na2tc_tokenized.txt
# na2tc.txt
# ./tokenized_data/outputs_en_2022/na2tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/na2tc_tokenized.txt
# na2tc.txt
# ./tokenized_data/outputs_en_2022/na2tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/na3tc_tokenized.txt
# na3tc.txt
# ./tokenized_data/outputs_en_2022/na3tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/na3tc_tokenized.txt
# na3tc.txt
# ./tokenized_data/outputs_en_2022/na3tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/na3tc_tokenized.txt
# na3tc.txt
# ./tokenized_data/outputs_en_2022/na3tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/na3tc_tokenized.txt
# na3tc.txt
# ./tokenized_data/outputs_en_2022/na3tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/na3tc_tokenized.txt
# na3tc.txt
# ./tokenized_data/outputs_en_2022/na3tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/na3tc_tokenized.txt
# na3tc.txt
# ./tokenized_data/outputs_en_2022/na3tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/na3tc_tokenized.txt
# na3tc.txt
# ./tokenized_data/outputs_en_2022/na3tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/na3tc_tokenized.txt
# na3tc.txt
# ./tokenized_data/outputs_en_2022/na3tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/na3tc_tokenized.txt
# na3tc.txt
# ./tokenized_data/outputs_en_2022/na3tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/na3tc_tokenized.txt
# na3tc.txt
# ./tokenized_data/outputs_en_2022/na3tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/na3tc_tokenized.txt
# na3tc.txt
# ./tokenized_data/outputs_en_2022/na3tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/na4tc_tokenized.txt
# na4tc.txt
# ./tokenized_data/outputs_en_2022/na4tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/na4tc_tokenized.txt
# na4tc.txt
# ./tokenized_data/outputs_en_2022/na4tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/na4tc_tokenized.txt
# na4tc.txt
# ./tokenized_data/outputs_en_2022/na4tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/na4tc_tokenized.txt
# na4tc.txt
# ./tokenized_data/outputs_en_2022/na4tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/na4tc_tokenized.txt
# na4tc.txt
# ./tokenized_data/outputs_en_2022/na4tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/na4tc_tokenized.txt
# na4tc.txt
# ./tokenized_data/outputs_en_2022/na4tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/na4tc_tokenized.txt
# na4tc.txt
# ./tokenized_data/outputs_en_2022/na4tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/na4tc_tokenized.txt
# na4tc.txt
# ./tokenized_data/outputs_en_2022/na4tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/na4tc_tokenized.txt
# na4tc.txt
# ./tokenized_data/outputs_en_2022/na4tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/na4tc_tokenized.txt
# na4tc.txt
# ./tokenized_data/outputs_en_2022/na4tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/na4tc_tokenized.txt
# na4tc.txt
# ./tokenized_data/outputs_en_2022/na4tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/na5tc_tokenized.txt
# na5tc.txt
# ./tokenized_data/outputs_en_2022/na5tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/na5tc_tokenized.txt
# na5tc.txt
# ./tokenized_data/outputs_en_2022/na5tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/na5tc_tokenized.txt
# na5tc.txt
# ./tokenized_data/outputs_en_2022/na5tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/na5tc_tokenized.txt
# na5tc.txt
# ./tokenized_data/outputs_en_2022/na5tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/na5tc_tokenized.txt
# na5tc.txt
# ./tokenized_data/outputs_en_2022/na5tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/na5tc_tokenized.txt
# na5tc.txt
# ./tokenized_data/outputs_en_2022/na5tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/na5tc_tokenized.txt
# na5tc.txt
# ./tokenized_data/outputs_en_2022/na5tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/na5tc_tokenized.txt
# na5tc.txt
# ./tokenized_data/outputs_en_2022/na5tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/na5tc_tokenized.txt
# na5tc.txt
# ./tokenized_data/outputs_en_2022/na5tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/na5tc_tokenized.txt
# na5tc.txt
# ./tokenized_data/outputs_en_2022/na5tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/na5tc_tokenized.txt
# na5tc.txt
# ./tokenized_data/outputs_en_2022/na5tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/na6tc_tokenized.txt
# na6tc.txt
# ./tokenized_data/outputs_en_2022/na6tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/na6tc_tokenized.txt
# na6tc.txt
# ./tokenized_data/outputs_en_2022/na6tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/na6tc_tokenized.txt
# na6tc.txt
# ./tokenized_data/outputs_en_2022/na6tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/na6tc_tokenized.txt
# na6tc.txt
# ./tokenized_data/outputs_en_2022/na6tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/na6tc_tokenized.txt
# na6tc.txt
# ./tokenized_data/outputs_en_2022/na6tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/na6tc_tokenized.txt
# na6tc.txt
# ./tokenized_data/outputs_en_2022/na6tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/na6tc_tokenized.txt
# na6tc.txt
# ./tokenized_data/outputs_en_2022/na6tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/na6tc_tokenized.txt
# na6tc.txt
# ./tokenized_data/outputs_en_2022/na6tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/na6tc_tokenized.txt
# na6tc.txt
# ./tokenized_data/outputs_en_2022/na6tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/na6tc_tokenized.txt
# na6tc.txt
# ./tokenized_data/outputs_en_2022/na6tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/na6tc_tokenized.txt
# na6tc.txt
# ./tokenized_data/outputs_en_2022/na6tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/na7tc_tokenized.txt
# na7tc.txt
# ./tokenized_data/outputs_en_2022/na7tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/na7tc_tokenized.txt
# na7tc.txt
# ./tokenized_data/outputs_en_2022/na7tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/na7tc_tokenized.txt
# na7tc.txt
# ./tokenized_data/outputs_en_2022/na7tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/na7tc_tokenized.txt
# na7tc.txt
# ./tokenized_data/outputs_en_2022/na7tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/na7tc_tokenized.txt
# na7tc.txt
# ./tokenized_data/outputs_en_2022/na7tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/na7tc_tokenized.txt
# na7tc.txt
# ./tokenized_data/outputs_en_2022/na7tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/na7tc_tokenized.txt
# na7tc.txt
# ./tokenized_data/outputs_en_2022/na7tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/na7tc_tokenized.txt
# na7tc.txt
# ./tokenized_data/outputs_en_2022/na7tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/na7tc_tokenized.txt
# na7tc.txt
# ./tokenized_data/outputs_en_2022/na7tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/na7tc_tokenized.txt
# na7tc.txt
# ./tokenized_data/outputs_en_2022/na7tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/na7tc_tokenized.txt
# na7tc.txt
# ./tokenized_data/outputs_en_2022/na7tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/pn1tc_tokenized.txt
# pn1tc.txt
# ./tokenized_data/outputs_en_2022/pn1tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/pn1tc_tokenized.txt
# pn1tc.txt
# ./tokenized_data/outputs_en_2022/pn1tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/pn1tc_tokenized.txt
# pn1tc.txt
# ./tokenized_data/outputs_en_2022/pn1tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/pn1tc_tokenized.txt
# pn1tc.txt
# ./tokenized_data/outputs_en_2022/pn1tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/pn1tc_tokenized.txt
# pn1tc.txt
# ./tokenized_data/outputs_en_2022/pn1tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/pn1tc_tokenized.txt
# pn1tc.txt
# ./tokenized_data/outputs_en_2022/pn1tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/pn1tc_tokenized.txt
# pn1tc.txt
# ./tokenized_data/outputs_en_2022/pn1tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/pn1tc_tokenized.txt
# pn1tc.txt
# ./tokenized_data/outputs_en_2022/pn1tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/pn1tc_tokenized.txt
# pn1tc.txt
# ./tokenized_data/outputs_en_2022/pn1tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/pn1tc_tokenized.txt
# pn1tc.txt
# ./tokenized_data/outputs_en_2022/pn1tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/pn1tc_tokenized.txt
# pn1tc.txt
# ./tokenized_data/outputs_en_2022/pn1tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/pn2tc_tokenized.txt
# pn2tc.txt
# ./tokenized_data/outputs_en_2022/pn2tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/pn2tc_tokenized.txt
# pn2tc.txt
# ./tokenized_data/outputs_en_2022/pn2tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/pn2tc_tokenized.txt
# pn2tc.txt
# ./tokenized_data/outputs_en_2022/pn2tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/pn2tc_tokenized.txt
# pn2tc.txt
# ./tokenized_data/outputs_en_2022/pn2tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/pn2tc_tokenized.txt
# pn2tc.txt
# ./tokenized_data/outputs_en_2022/pn2tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/pn2tc_tokenized.txt
# pn2tc.txt
# ./tokenized_data/outputs_en_2022/pn2tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/pn2tc_tokenized.txt
# pn2tc.txt
# ./tokenized_data/outputs_en_2022/pn2tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/pn2tc_tokenized.txt
# pn2tc.txt
# ./tokenized_data/outputs_en_2022/pn2tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/pn2tc_tokenized.txt
# pn2tc.txt
# ./tokenized_data/outputs_en_2022/pn2tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/pn2tc_tokenized.txt
# pn2tc.txt
# ./tokenized_data/outputs_en_2022/pn2tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/pn2tc_tokenized.txt
# pn2tc.txt
# ./tokenized_data/outputs_en_2022/pn2tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/pn3tc_tokenized.txt
# pn3tc.txt
# ./tokenized_data/outputs_en_2022/pn3tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/pn3tc_tokenized.txt
# pn3tc.txt
# ./tokenized_data/outputs_en_2022/pn3tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/pn3tc_tokenized.txt
# pn3tc.txt
# ./tokenized_data/outputs_en_2022/pn3tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/pn3tc_tokenized.txt
# pn3tc.txt
# ./tokenized_data/outputs_en_2022/pn3tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/pn3tc_tokenized.txt
# pn3tc.txt
# ./tokenized_data/outputs_en_2022/pn3tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/pn3tc_tokenized.txt
# pn3tc.txt
# ./tokenized_data/outputs_en_2022/pn3tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/pn3tc_tokenized.txt
# pn3tc.txt
# ./tokenized_data/outputs_en_2022/pn3tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/pn3tc_tokenized.txt
# pn3tc.txt
# ./tokenized_data/outputs_en_2022/pn3tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/pn3tc_tokenized.txt
# pn3tc.txt
# ./tokenized_data/outputs_en_2022/pn3tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/pn3tc_tokenized.txt
# pn3tc.txt
# ./tokenized_data/outputs_en_2022/pn3tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/pn3tc_tokenized.txt
# pn3tc.txt
# ./tokenized_data/outputs_en_2022/pn3tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/pn4tc_tokenized.txt
# pn4tc.txt
# ./tokenized_data/outputs_en_2022/pn4tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/pn4tc_tokenized.txt
# pn4tc.txt
# ./tokenized_data/outputs_en_2022/pn4tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/pn4tc_tokenized.txt
# pn4tc.txt
# ./tokenized_data/outputs_en_2022/pn4tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/pn4tc_tokenized.txt
# pn4tc.txt
# ./tokenized_data/outputs_en_2022/pn4tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/pn4tc_tokenized.txt
# pn4tc.txt
# ./tokenized_data/outputs_en_2022/pn4tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/pn4tc_tokenized.txt
# pn4tc.txt
# ./tokenized_data/outputs_en_2022/pn4tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/pn4tc_tokenized.txt
# pn4tc.txt
# ./tokenized_data/outputs_en_2022/pn4tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/pn4tc_tokenized.txt
# pn4tc.txt
# ./tokenized_data/outputs_en_2022/pn4tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/pn4tc_tokenized.txt
# pn4tc.txt
# ./tokenized_data/outputs_en_2022/pn4tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/pn4tc_tokenized.txt
# pn4tc.txt
# ./tokenized_data/outputs_en_2022/pn4tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/pn4tc_tokenized.txt
# pn4tc.txt
# ./tokenized_data/outputs_en_2022/pn4tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/pn5tc_tokenized.txt
# pn5tc.txt
# ./tokenized_data/outputs_en_2022/pn5tc/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/pn5tc_tokenized.txt
# pn5tc.txt
# ./tokenized_data/outputs_en_2022/pn5tc/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/pn5tc_tokenized.txt
# pn5tc.txt
# ./tokenized_data/outputs_en_2022/pn5tc/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/pn5tc_tokenized.txt
# pn5tc.txt
# ./tokenized_data/outputs_en_2022/pn5tc/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/pn5tc_tokenized.txt
# pn5tc.txt
# ./tokenized_data/outputs_en_2022/pn5tc/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/pn5tc_tokenized.txt
# pn5tc.txt
# ./tokenized_data/outputs_en_2022/pn5tc/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/pn5tc_tokenized.txt
# pn5tc.txt
# ./tokenized_data/outputs_en_2022/pn5tc/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/pn5tc_tokenized.txt
# pn5tc.txt
# ./tokenized_data/outputs_en_2022/pn5tc/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/pn5tc_tokenized.txt
# pn5tc.txt
# ./tokenized_data/outputs_en_2022/pn5tc/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/pn5tc_tokenized.txt
# pn5tc.txt
# ./tokenized_data/outputs_en_2022/pn5tc/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/pn5tc_tokenized.txt
# pn5tc.txt
# ./tokenized_data/outputs_en_2022/pn5tc/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/robot_tokenized.txt
# robot.txt
# ./tokenized_data/outputs_en_2022/robot/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/robot_tokenized.txt
# robot.txt
# ./tokenized_data/outputs_en_2022/robot/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/robot_tokenized.txt
# robot.txt
# ./tokenized_data/outputs_en_2022/robot/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/robot_tokenized.txt
# robot.txt
# ./tokenized_data/outputs_en_2022/robot/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/robot_tokenized.txt
# robot.txt
# ./tokenized_data/outputs_en_2022/robot/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/robot_tokenized.txt
# robot.txt
# ./tokenized_data/outputs_en_2022/robot/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/robot_tokenized.txt
# robot.txt
# ./tokenized_data/outputs_en_2022/robot/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/robot_tokenized.txt
# robot.txt
# ./tokenized_data/outputs_en_2022/robot/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/robot_tokenized.txt
# robot.txt
# ./tokenized_data/outputs_en_2022/robot/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/robot_tokenized.txt
# robot.txt
# ./tokenized_data/outputs_en_2022/robot/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/robot_tokenized.txt
# robot.txt
# ./tokenized_data/outputs_en_2022/robot/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/SLA_tokenized.txt
# SLA.txt
# ./tokenized_data/outputs_en_2022/SLA/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/SLA_tokenized.txt
# SLA.txt
# ./tokenized_data/outputs_en_2022/SLA/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/SLA_tokenized.txt
# SLA.txt
# ./tokenized_data/outputs_en_2022/SLA/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/SLA_tokenized.txt
# SLA.txt
# ./tokenized_data/outputs_en_2022/SLA/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/SLA_tokenized.txt
# SLA.txt
# ./tokenized_data/outputs_en_2022/SLA/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/SLA_tokenized.txt
# SLA.txt
# ./tokenized_data/outputs_en_2022/SLA/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/SLA_tokenized.txt
# SLA.txt
# ./tokenized_data/outputs_en_2022/SLA/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/SLA_tokenized.txt
# SLA.txt
# ./tokenized_data/outputs_en_2022/SLA/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/SLA_tokenized.txt
# SLA.txt
# ./tokenized_data/outputs_en_2022/SLA/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/SLA_tokenized.txt
# SLA.txt
# ./tokenized_data/outputs_en_2022/SLA/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/SLA_tokenized.txt
# SLA.txt
# ./tokenized_data/outputs_en_2022/SLA/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt
# ./tokenized_data/inputs_cs/sublease_tokenized.txt
# sublease.txt
# ./tokenized_data/outputs_en_2022/sublease/ALMAnaCH-Inria_tokenized.txt
# ALMAnaCH-Inria.txt
# ./tokenized_data/inputs_cs/sublease_tokenized.txt
# sublease.txt
# ./tokenized_data/outputs_en_2022/sublease/CUNI-DocTransformer_tokenized.txt
# CUNI-DocTransformer.txt
# ./tokenized_data/inputs_cs/sublease_tokenized.txt
# sublease.txt
# ./tokenized_data/outputs_en_2022/sublease/CUNI-Transformer_tokenized.txt
# CUNI-Transformer.txt
# ./tokenized_data/inputs_cs/sublease_tokenized.txt
# sublease.txt
# ./tokenized_data/outputs_en_2022/sublease/JDExploreAcademy_tokenized.txt
# JDExploreAcademy.txt
# ./tokenized_data/inputs_cs/sublease_tokenized.txt
# sublease.txt
# ./tokenized_data/outputs_en_2022/sublease/Lan-Bridge_tokenized.txt
# Lan-Bridge.txt
# ./tokenized_data/inputs_cs/sublease_tokenized.txt
# sublease.txt
# ./tokenized_data/outputs_en_2022/sublease/Online-A_tokenized.txt
# Online-A.txt
# ./tokenized_data/inputs_cs/sublease_tokenized.txt
# sublease.txt
# ./tokenized_data/outputs_en_2022/sublease/Online-B_tokenized.txt
# Online-B.txt
# ./tokenized_data/inputs_cs/sublease_tokenized.txt
# sublease.txt
# ./tokenized_data/outputs_en_2022/sublease/Online-G_tokenized.txt
# Online-G.txt
# ./tokenized_data/inputs_cs/sublease_tokenized.txt
# sublease.txt
# ./tokenized_data/outputs_en_2022/sublease/Online-W_tokenized.txt
# Online-W.txt
# ./tokenized_data/inputs_cs/sublease_tokenized.txt
# sublease.txt
# ./tokenized_data/outputs_en_2022/sublease/Online-Y_tokenized.txt
# Online-Y.txt
# ./tokenized_data/inputs_cs/sublease_tokenized.txt
# sublease.txt
# ./tokenized_data/outputs_en_2022/sublease/SHOPLINE-PL_tokenized.txt
# SHOPLINE-PL.txt

# %%
bitexts = os.listdir('./alignments/2021/bitexts/')

# %%
bitexts
# Out:
# ['au1tc_CUNI-DocTransformer.s',
#  'au1tc_CUNI-Transformer2018.s',
#  'au1tc_Facebook-AI.s',
#  'au1tc_Online-A.s',
#  'au1tc_Online-B.s',
#  'au1tc_Online-G.s',
#  'au1tc_Online-W.s',
#  'au1tc_Online-Y.s',
#  'au2tc_CUNI-DocTransformer.s',
#  'au2tc_CUNI-Transformer2018.s',
#  'au2tc_Facebook-AI.s',
#  'au2tc_Online-A.s',
#  'au2tc_Online-B.s',
#  'au2tc_Online-G.s',
#  'au2tc_Online-W.s',
#  'au2tc_Online-Y.s',
#  'au3tc_CUNI-DocTransformer.s',
#  'au3tc_CUNI-Transformer2018.s',
#  'au3tc_Facebook-AI.s',
#  'au3tc_Online-A.s',
#  'au3tc_Online-B.s',
#  'au3tc_Online-G.s',
#  'au3tc_Online-W.s',
#  'au3tc_Online-Y.s',
#  'au4tc_CUNI-DocTransformer.s',
#  'au4tc_CUNI-Transformer2018.s',
#  'au4tc_Facebook-AI.s',
#  'au4tc_Online-A.s',
#  'au4tc_Online-B.s',
#  'au4tc_Online-G.s',
#  'au4tc_Online-W.s',
#  'au4tc_Online-Y.s',
#  'au5tc_CUNI-DocTransformer.s',
#  'au5tc_CUNI-Transformer2018.s',
#  'au5tc_Facebook-AI.s',
#  'au5tc_Online-A.s',
#  'au5tc_Online-B.s',
#  'au5tc_Online-G.s',
#  'au5tc_Online-W.s',
#  'au5tc_Online-Y.s',
#  'au6tc_CUNI-DocTransformer.s',
#  'au6tc_CUNI-Transformer2018.s',
#  'au6tc_Facebook-AI.s',
#  'au6tc_Online-A.s',
#  'au6tc_Online-B.s',
#  'au6tc_Online-G.s',
#  'au6tc_Online-W.s',
#  'au6tc_Online-Y.s',
#  'au7tc_CUNI-DocTransformer.s',
#  'au7tc_CUNI-Transformer2018.s',
#  'au7tc_Facebook-AI.s',
#  'au7tc_Online-A.s',
#  'au7tc_Online-B.s',
#  'au7tc_Online-G.s',
#  'au7tc_Online-W.s',
#  'au7tc_Online-Y.s',
#  'au8tc_CUNI-DocTransformer.s',
#  'au8tc_CUNI-Transformer2018.s',
#  'au8tc_Facebook-AI.s',
#  'au8tc_Online-A.s',
#  'au8tc_Online-B.s',
#  'au8tc_Online-G.s',
#  'au8tc_Online-W.s',
#  'au8tc_Online-Y.s',
#  'au9tc_CUNI-DocTransformer.s',
#  'au9tc_CUNI-Transformer2018.s',
#  'au9tc_Facebook-AI.s',
#  'au9tc_Online-A.s',
#  'au9tc_Online-B.s',
#  'au9tc_Online-G.s',
#  'au9tc_Online-W.s',
#  'au9tc_Online-Y.s',
#  'kn1tc_CUNI-DocTransformer.s',
#  'kn1tc_CUNI-Transformer2018.s',
#  'kn1tc_Facebook-AI.s',
#  'kn1tc_Online-A.s',
#  'kn1tc_Online-B.s',
#  'kn1tc_Online-G.s',
#  'kn1tc_Online-W.s',
#  'kn1tc_Online-Y.s',
#  'kn2tc_CUNI-DocTransformer.s',
#  'kn2tc_CUNI-Transformer2018.s',
#  'kn2tc_Facebook-AI.s',
#  'kn2tc_Online-A.s',
#  'kn2tc_Online-B.s',
#  'kn2tc_Online-G.s',
#  'kn2tc_Online-W.s',
#  'kn2tc_Online-Y.s',
#  'kn3tc_CUNI-DocTransformer.s',
#  'kn3tc_CUNI-Transformer2018.s',
#  'kn3tc_Facebook-AI.s',
#  'kn3tc_Online-A.s',
#  'kn3tc_Online-B.s',
#  'kn3tc_Online-G.s',
#  'kn3tc_Online-W.s',
#  'kn3tc_Online-Y.s',
#  'kn4tc_CUNI-DocTransformer.s',
#  'kn4tc_CUNI-Transformer2018.s',
#  'kn4tc_Facebook-AI.s',
#  'kn4tc_Online-A.s',
#  'kn4tc_Online-B.s',
#  'kn4tc_Online-G.s',
#  'kn4tc_Online-W.s',
#  'kn4tc_Online-Y.s',
#  'kn5tc_CUNI-DocTransformer.s',
#  'kn5tc_CUNI-Transformer2018.s',
#  'kn5tc_Facebook-AI.s',
#  'kn5tc_Online-A.s',
#  'kn5tc_Online-B.s',
#  'kn5tc_Online-G.s',
#  'kn5tc_Online-W.s',
#  'kn5tc_Online-Y.s',
#  'kn6tc_CUNI-DocTransformer.s',
#  'kn6tc_CUNI-Transformer2018.s',
#  'kn6tc_Facebook-AI.s',
#  'kn6tc_Online-A.s',
#  'kn6tc_Online-B.s',
#  'kn6tc_Online-G.s',
#  'kn6tc_Online-W.s',
#  'kn6tc_Online-Y.s',
#  'kn7tc_CUNI-DocTransformer.s',
#  'kn7tc_CUNI-Transformer2018.s',
#  'kn7tc_Facebook-AI.s',
#  'kn7tc_Online-A.s',
#  'kn7tc_Online-B.s',
#  'kn7tc_Online-G.s',
#  'kn7tc_Online-W.s',
#  'kn7tc_Online-Y.s',
#  'kn8tc_CUNI-DocTransformer.s',
#  'kn8tc_CUNI-Transformer2018.s',
#  'kn8tc_Facebook-AI.s',
#  'kn8tc_Online-A.s',
#  'kn8tc_Online-B.s',
#  'kn8tc_Online-G.s',
#  'kn8tc_Online-W.s',
#  'kn8tc_Online-Y.s',
#  'kn9tc_CUNI-DocTransformer.s',
#  'kn9tc_CUNI-Transformer2018.s',
#  'kn9tc_Facebook-AI.s',
#  'kn9tc_Online-A.s',
#  'kn9tc_Online-B.s',
#  'kn9tc_Online-G.s',
#  'kn9tc_Online-W.s',
#  'kn9tc_Online-Y.s',
#  'na1tc_CUNI-DocTransformer.s',
#  'na1tc_CUNI-Transformer2018.s',
#  'na1tc_Facebook-AI.s',
#  'na1tc_Online-A.s',
#  'na1tc_Online-B.s',
#  'na1tc_Online-G.s',
#  'na1tc_Online-W.s',
#  'na1tc_Online-Y.s',
#  'na2tc_CUNI-DocTransformer.s',
#  'na2tc_CUNI-Transformer2018.s',
#  'na2tc_Facebook-AI.s',
#  'na2tc_Online-A.s',
#  'na2tc_Online-B.s',
#  'na2tc_Online-G.s',
#  'na2tc_Online-W.s',
#  'na2tc_Online-Y.s',
#  'na3tc_CUNI-DocTransformer.s',
#  'na3tc_CUNI-Transformer2018.s',
#  'na3tc_Facebook-AI.s',
#  'na3tc_Online-A.s',
#  'na3tc_Online-B.s',
#  'na3tc_Online-G.s',
#  'na3tc_Online-W.s',
#  'na3tc_Online-Y.s',
#  'na4tc_CUNI-DocTransformer.s',
#  'na4tc_CUNI-Transformer2018.s',
#  'na4tc_Facebook-AI.s',
#  'na4tc_Online-A.s',
#  'na4tc_Online-B.s',
#  'na4tc_Online-G.s',
#  'na4tc_Online-W.s',
#  'na4tc_Online-Y.s',
#  'na5tc_CUNI-DocTransformer.s',
#  'na5tc_CUNI-Transformer2018.s',
#  'na5tc_Facebook-AI.s',
#  'na5tc_Online-A.s',
#  'na5tc_Online-B.s',
#  'na5tc_Online-G.s',
#  'na5tc_Online-W.s',
#  'na5tc_Online-Y.s',
#  'na6tc_CUNI-DocTransformer.s',
#  'na6tc_CUNI-Transformer2018.s',
#  'na6tc_Facebook-AI.s',
#  'na6tc_Online-A.s',
#  'na6tc_Online-B.s',
#  'na6tc_Online-G.s',
#  'na6tc_Online-W.s',
#  'na6tc_Online-Y.s',
#  'na7tc_CUNI-DocTransformer.s',
#  'na7tc_CUNI-Transformer2018.s',
#  'na7tc_Facebook-AI.s',
#  'na7tc_Online-A.s',
#  'na7tc_Online-B.s',
#  'na7tc_Online-G.s',
#  'na7tc_Online-W.s',
#  'na7tc_Online-Y.s',
#  'pn1tc_CUNI-DocTransformer.s',
#  'pn1tc_CUNI-Transformer2018.s',
#  'pn1tc_Facebook-AI.s',
#  'pn1tc_Online-A.s',
#  'pn1tc_Online-B.s',
#  'pn1tc_Online-G.s',
#  'pn1tc_Online-W.s',
#  'pn1tc_Online-Y.s',
#  'pn2tc_CUNI-DocTransformer.s',
#  'pn2tc_CUNI-Transformer2018.s',
#  'pn2tc_Facebook-AI.s',
#  'pn2tc_Online-A.s',
#  'pn2tc_Online-B.s',
#  'pn2tc_Online-G.s',
#  'pn2tc_Online-W.s',
#  'pn2tc_Online-Y.s',
#  'pn3tc_CUNI-DocTransformer.s',
#  'pn3tc_CUNI-Transformer2018.s',
#  'pn3tc_Facebook-AI.s',
#  'pn3tc_Online-A.s',
#  'pn3tc_Online-B.s',
#  'pn3tc_Online-G.s',
#  'pn3tc_Online-W.s',
#  'pn3tc_Online-Y.s',
#  'pn4tc_CUNI-DocTransformer.s',
#  'pn4tc_CUNI-Transformer2018.s',
#  'pn4tc_Facebook-AI.s',
#  'pn4tc_Online-A.s',
#  'pn4tc_Online-B.s',
#  'pn4tc_Online-G.s',
#  'pn4tc_Online-W.s',
#  'pn4tc_Online-Y.s',
#  'pn5tc_CUNI-DocTransformer.s',
#  'pn5tc_CUNI-Transformer2018.s',
#  'pn5tc_Facebook-AI.s',
#  'pn5tc_Online-A.s',
#  'pn5tc_Online-B.s',
#  'pn5tc_Online-G.s',
#  'pn5tc_Online-W.s',
#  'pn5tc_Online-Y.s',
#  'robot_CUNI-DocTransformer.s',
#  'robot_CUNI-Transformer2018.s',
#  'robot_Facebook-AI.s',
#  'robot_Online-A.s',
#  'robot_Online-B.s',
#  'robot_Online-G.s',
#  'robot_Online-W.s',
#  'robot_Online-Y.s',
#  'SLA_CUNI-DocTransformer.s',
#  'SLA_CUNI-Transformer2018.s',
#  'SLA_Facebook-AI.s',
#  'SLA_Online-A.s',
#  'SLA_Online-B.s',
#  'SLA_Online-G.s',
#  'SLA_Online-W.s',
#  'SLA_Online-Y.s',
#  'sublease_CUNI-DocTransformer.s',
#  'sublease_CUNI-Transformer2018.s',
#  'sublease_Facebook-AI.s',
#  'sublease_Online-A.s',
#  'sublease_Online-B.s',
#  'sublease_Online-G.s',
#  'sublease_Online-W.s',
#  'sublease_Online-Y.s']

# %%
import pandas as pd 

bitexts_doc_list = list(set([bitext.split('_')[0] for bitext in bitexts]))
bitexts_alg_list = list(set([bitext.split('_')[1][:-2] for bitext in bitexts]))

#bitexts_split = pd.DataFrame(bitexts_split, columns=['doc', 'alg'])

# %%
for alg in bitexts_alg_list:
    for doc in bitexts_doc_list:
        filename = doc + '_' + alg + '.s'
        print(filename)
# Out:
# pn4tc_Online-W.s
# au9tc_Online-W.s
# pn1tc_Online-W.s
# pn3tc_Online-W.s
# robot_Online-W.s
# na3tc_Online-W.s
# kn5tc_Online-W.s
# au7tc_Online-W.s
# pn2tc_Online-W.s
# na6tc_Online-W.s
# au2tc_Online-W.s
# na7tc_Online-W.s
# au6tc_Online-W.s
# kn7tc_Online-W.s
# kn6tc_Online-W.s
# SLA_Online-W.s
# sublease_Online-W.s
# kn4tc_Online-W.s
# kn9tc_Online-W.s
# kn2tc_Online-W.s
# kn1tc_Online-W.s
# au8tc_Online-W.s
# au1tc_Online-W.s
# kn8tc_Online-W.s
# au3tc_Online-W.s
# na4tc_Online-W.s
# pn5tc_Online-W.s
# kn3tc_Online-W.s
# na1tc_Online-W.s
# au4tc_Online-W.s
# na5tc_Online-W.s
# au5tc_Online-W.s
# na2tc_Online-W.s
# pn4tc_Facebook-AI.s
# au9tc_Facebook-AI.s
# pn1tc_Facebook-AI.s
# pn3tc_Facebook-AI.s
# robot_Facebook-AI.s
# na3tc_Facebook-AI.s
# kn5tc_Facebook-AI.s
# au7tc_Facebook-AI.s
# pn2tc_Facebook-AI.s
# na6tc_Facebook-AI.s
# au2tc_Facebook-AI.s
# na7tc_Facebook-AI.s
# au6tc_Facebook-AI.s
# kn7tc_Facebook-AI.s
# kn6tc_Facebook-AI.s
# SLA_Facebook-AI.s
# sublease_Facebook-AI.s
# kn4tc_Facebook-AI.s
# kn9tc_Facebook-AI.s
# kn2tc_Facebook-AI.s
# kn1tc_Facebook-AI.s
# au8tc_Facebook-AI.s
# au1tc_Facebook-AI.s
# kn8tc_Facebook-AI.s
# au3tc_Facebook-AI.s
# na4tc_Facebook-AI.s
# pn5tc_Facebook-AI.s
# kn3tc_Facebook-AI.s
# na1tc_Facebook-AI.s
# au4tc_Facebook-AI.s
# na5tc_Facebook-AI.s
# au5tc_Facebook-AI.s
# na2tc_Facebook-AI.s
# pn4tc_Online-Y.s
# au9tc_Online-Y.s
# pn1tc_Online-Y.s
# pn3tc_Online-Y.s
# robot_Online-Y.s
# na3tc_Online-Y.s
# kn5tc_Online-Y.s
# au7tc_Online-Y.s
# pn2tc_Online-Y.s
# na6tc_Online-Y.s
# au2tc_Online-Y.s
# na7tc_Online-Y.s
# au6tc_Online-Y.s
# kn7tc_Online-Y.s
# kn6tc_Online-Y.s
# SLA_Online-Y.s
# sublease_Online-Y.s
# kn4tc_Online-Y.s
# kn9tc_Online-Y.s
# kn2tc_Online-Y.s
# kn1tc_Online-Y.s
# au8tc_Online-Y.s
# au1tc_Online-Y.s
# kn8tc_Online-Y.s
# au3tc_Online-Y.s
# na4tc_Online-Y.s
# pn5tc_Online-Y.s
# kn3tc_Online-Y.s
# na1tc_Online-Y.s
# au4tc_Online-Y.s
# na5tc_Online-Y.s
# au5tc_Online-Y.s
# na2tc_Online-Y.s
# pn4tc_Online-G.s
# au9tc_Online-G.s
# pn1tc_Online-G.s
# pn3tc_Online-G.s
# robot_Online-G.s
# na3tc_Online-G.s
# kn5tc_Online-G.s
# au7tc_Online-G.s
# pn2tc_Online-G.s
# na6tc_Online-G.s
# au2tc_Online-G.s
# na7tc_Online-G.s
# au6tc_Online-G.s
# kn7tc_Online-G.s
# kn6tc_Online-G.s
# SLA_Online-G.s
# sublease_Online-G.s
# kn4tc_Online-G.s
# kn9tc_Online-G.s
# kn2tc_Online-G.s
# kn1tc_Online-G.s
# au8tc_Online-G.s
# au1tc_Online-G.s
# kn8tc_Online-G.s
# au3tc_Online-G.s
# na4tc_Online-G.s
# pn5tc_Online-G.s
# kn3tc_Online-G.s
# na1tc_Online-G.s
# au4tc_Online-G.s
# na5tc_Online-G.s
# au5tc_Online-G.s
# na2tc_Online-G.s
# pn4tc_Online-B.s
# au9tc_Online-B.s
# pn1tc_Online-B.s
# pn3tc_Online-B.s
# robot_Online-B.s
# na3tc_Online-B.s
# kn5tc_Online-B.s
# au7tc_Online-B.s
# pn2tc_Online-B.s
# na6tc_Online-B.s
# au2tc_Online-B.s
# na7tc_Online-B.s
# au6tc_Online-B.s
# kn7tc_Online-B.s
# kn6tc_Online-B.s
# SLA_Online-B.s
# sublease_Online-B.s
# kn4tc_Online-B.s
# kn9tc_Online-B.s
# kn2tc_Online-B.s
# kn1tc_Online-B.s
# au8tc_Online-B.s
# au1tc_Online-B.s
# kn8tc_Online-B.s
# au3tc_Online-B.s
# na4tc_Online-B.s
# pn5tc_Online-B.s
# kn3tc_Online-B.s
# na1tc_Online-B.s
# au4tc_Online-B.s
# na5tc_Online-B.s
# au5tc_Online-B.s
# na2tc_Online-B.s
# pn4tc_CUNI-Transformer2018.s
# au9tc_CUNI-Transformer2018.s
# pn1tc_CUNI-Transformer2018.s
# pn3tc_CUNI-Transformer2018.s
# robot_CUNI-Transformer2018.s
# na3tc_CUNI-Transformer2018.s
# kn5tc_CUNI-Transformer2018.s
# au7tc_CUNI-Transformer2018.s
# pn2tc_CUNI-Transformer2018.s
# na6tc_CUNI-Transformer2018.s
# au2tc_CUNI-Transformer2018.s
# na7tc_CUNI-Transformer2018.s
# au6tc_CUNI-Transformer2018.s
# kn7tc_CUNI-Transformer2018.s
# kn6tc_CUNI-Transformer2018.s
# SLA_CUNI-Transformer2018.s
# sublease_CUNI-Transformer2018.s
# kn4tc_CUNI-Transformer2018.s
# kn9tc_CUNI-Transformer2018.s
# kn2tc_CUNI-Transformer2018.s
# kn1tc_CUNI-Transformer2018.s
# au8tc_CUNI-Transformer2018.s
# au1tc_CUNI-Transformer2018.s
# kn8tc_CUNI-Transformer2018.s
# au3tc_CUNI-Transformer2018.s
# na4tc_CUNI-Transformer2018.s
# pn5tc_CUNI-Transformer2018.s
# kn3tc_CUNI-Transformer2018.s
# na1tc_CUNI-Transformer2018.s
# au4tc_CUNI-Transformer2018.s
# na5tc_CUNI-Transformer2018.s
# au5tc_CUNI-Transformer2018.s
# na2tc_CUNI-Transformer2018.s
# pn4tc_CUNI-DocTransformer.s
# au9tc_CUNI-DocTransformer.s
# pn1tc_CUNI-DocTransformer.s
# pn3tc_CUNI-DocTransformer.s
# robot_CUNI-DocTransformer.s
# na3tc_CUNI-DocTransformer.s
# kn5tc_CUNI-DocTransformer.s
# au7tc_CUNI-DocTransformer.s
# pn2tc_CUNI-DocTransformer.s
# na6tc_CUNI-DocTransformer.s
# au2tc_CUNI-DocTransformer.s
# na7tc_CUNI-DocTransformer.s
# au6tc_CUNI-DocTransformer.s
# kn7tc_CUNI-DocTransformer.s
# kn6tc_CUNI-DocTransformer.s
# SLA_CUNI-DocTransformer.s
# sublease_CUNI-DocTransformer.s
# kn4tc_CUNI-DocTransformer.s
# kn9tc_CUNI-DocTransformer.s
# kn2tc_CUNI-DocTransformer.s
# kn1tc_CUNI-DocTransformer.s
# au8tc_CUNI-DocTransformer.s
# au1tc_CUNI-DocTransformer.s
# kn8tc_CUNI-DocTransformer.s
# au3tc_CUNI-DocTransformer.s
# na4tc_CUNI-DocTransformer.s
# pn5tc_CUNI-DocTransformer.s
# kn3tc_CUNI-DocTransformer.s
# na1tc_CUNI-DocTransformer.s
# au4tc_CUNI-DocTransformer.s
# na5tc_CUNI-DocTransformer.s
# au5tc_CUNI-DocTransformer.s
# na2tc_CUNI-DocTransformer.s
# pn4tc_Online-A.s
# au9tc_Online-A.s
# pn1tc_Online-A.s
# pn3tc_Online-A.s
# robot_Online-A.s
# na3tc_Online-A.s
# kn5tc_Online-A.s
# au7tc_Online-A.s
# pn2tc_Online-A.s
# na6tc_Online-A.s
# au2tc_Online-A.s
# na7tc_Online-A.s
# au6tc_Online-A.s
# kn7tc_Online-A.s
# kn6tc_Online-A.s
# SLA_Online-A.s
# sublease_Online-A.s
# kn4tc_Online-A.s
# kn9tc_Online-A.s
# kn2tc_Online-A.s
# kn1tc_Online-A.s
# au8tc_Online-A.s
# au1tc_Online-A.s
# kn8tc_Online-A.s
# au3tc_Online-A.s
# na4tc_Online-A.s
# pn5tc_Online-A.s
# kn3tc_Online-A.s
# na1tc_Online-A.s
# au4tc_Online-A.s
# na5tc_Online-A.s
# au5tc_Online-A.s
# na2tc_Online-A.s

# %%
bitexts
# Out:
# ['au1tc_CUNI-DocTransformer.s',
#  'au1tc_CUNI-Transformer2018.s',
#  'au1tc_Facebook-AI.s',
#  'au1tc_Online-A.s',
#  'au1tc_Online-B.s',
#  'au1tc_Online-G.s',
#  'au1tc_Online-W.s',
#  'au1tc_Online-Y.s',
#  'au2tc_CUNI-DocTransformer.s',
#  'au2tc_CUNI-Transformer2018.s',
#  'au2tc_Facebook-AI.s',
#  'au2tc_Online-A.s',
#  'au2tc_Online-B.s',
#  'au2tc_Online-G.s',
#  'au2tc_Online-W.s',
#  'au2tc_Online-Y.s',
#  'au3tc_CUNI-DocTransformer.s',
#  'au3tc_CUNI-Transformer2018.s',
#  'au3tc_Facebook-AI.s',
#  'au3tc_Online-A.s',
#  'au3tc_Online-B.s',
#  'au3tc_Online-G.s',
#  'au3tc_Online-W.s',
#  'au3tc_Online-Y.s',
#  'au4tc_CUNI-DocTransformer.s',
#  'au4tc_CUNI-Transformer2018.s',
#  'au4tc_Facebook-AI.s',
#  'au4tc_Online-A.s',
#  'au4tc_Online-B.s',
#  'au4tc_Online-G.s',
#  'au4tc_Online-W.s',
#  'au4tc_Online-Y.s',
#  'au5tc_CUNI-DocTransformer.s',
#  'au5tc_CUNI-Transformer2018.s',
#  'au5tc_Facebook-AI.s',
#  'au5tc_Online-A.s',
#  'au5tc_Online-B.s',
#  'au5tc_Online-G.s',
#  'au5tc_Online-W.s',
#  'au5tc_Online-Y.s',
#  'au6tc_CUNI-DocTransformer.s',
#  'au6tc_CUNI-Transformer2018.s',
#  'au6tc_Facebook-AI.s',
#  'au6tc_Online-A.s',
#  'au6tc_Online-B.s',
#  'au6tc_Online-G.s',
#  'au6tc_Online-W.s',
#  'au6tc_Online-Y.s',
#  'au7tc_CUNI-DocTransformer.s',
#  'au7tc_CUNI-Transformer2018.s',
#  'au7tc_Facebook-AI.s',
#  'au7tc_Online-A.s',
#  'au7tc_Online-B.s',
#  'au7tc_Online-G.s',
#  'au7tc_Online-W.s',
#  'au7tc_Online-Y.s',
#  'au8tc_CUNI-DocTransformer.s',
#  'au8tc_CUNI-Transformer2018.s',
#  'au8tc_Facebook-AI.s',
#  'au8tc_Online-A.s',
#  'au8tc_Online-B.s',
#  'au8tc_Online-G.s',
#  'au8tc_Online-W.s',
#  'au8tc_Online-Y.s',
#  'au9tc_CUNI-DocTransformer.s',
#  'au9tc_CUNI-Transformer2018.s',
#  'au9tc_Facebook-AI.s',
#  'au9tc_Online-A.s',
#  'au9tc_Online-B.s',
#  'au9tc_Online-G.s',
#  'au9tc_Online-W.s',
#  'au9tc_Online-Y.s',
#  'kn1tc_CUNI-DocTransformer.s',
#  'kn1tc_CUNI-Transformer2018.s',
#  'kn1tc_Facebook-AI.s',
#  'kn1tc_Online-A.s',
#  'kn1tc_Online-B.s',
#  'kn1tc_Online-G.s',
#  'kn1tc_Online-W.s',
#  'kn1tc_Online-Y.s',
#  'kn2tc_CUNI-DocTransformer.s',
#  'kn2tc_CUNI-Transformer2018.s',
#  'kn2tc_Facebook-AI.s',
#  'kn2tc_Online-A.s',
#  'kn2tc_Online-B.s',
#  'kn2tc_Online-G.s',
#  'kn2tc_Online-W.s',
#  'kn2tc_Online-Y.s',
#  'kn3tc_CUNI-DocTransformer.s',
#  'kn3tc_CUNI-Transformer2018.s',
#  'kn3tc_Facebook-AI.s',
#  'kn3tc_Online-A.s',
#  'kn3tc_Online-B.s',
#  'kn3tc_Online-G.s',
#  'kn3tc_Online-W.s',
#  'kn3tc_Online-Y.s',
#  'kn4tc_CUNI-DocTransformer.s',
#  'kn4tc_CUNI-Transformer2018.s',
#  'kn4tc_Facebook-AI.s',
#  'kn4tc_Online-A.s',
#  'kn4tc_Online-B.s',
#  'kn4tc_Online-G.s',
#  'kn4tc_Online-W.s',
#  'kn4tc_Online-Y.s',
#  'kn5tc_CUNI-DocTransformer.s',
#  'kn5tc_CUNI-Transformer2018.s',
#  'kn5tc_Facebook-AI.s',
#  'kn5tc_Online-A.s',
#  'kn5tc_Online-B.s',
#  'kn5tc_Online-G.s',
#  'kn5tc_Online-W.s',
#  'kn5tc_Online-Y.s',
#  'kn6tc_CUNI-DocTransformer.s',
#  'kn6tc_CUNI-Transformer2018.s',
#  'kn6tc_Facebook-AI.s',
#  'kn6tc_Online-A.s',
#  'kn6tc_Online-B.s',
#  'kn6tc_Online-G.s',
#  'kn6tc_Online-W.s',
#  'kn6tc_Online-Y.s',
#  'kn7tc_CUNI-DocTransformer.s',
#  'kn7tc_CUNI-Transformer2018.s',
#  'kn7tc_Facebook-AI.s',
#  'kn7tc_Online-A.s',
#  'kn7tc_Online-B.s',
#  'kn7tc_Online-G.s',
#  'kn7tc_Online-W.s',
#  'kn7tc_Online-Y.s',
#  'kn8tc_CUNI-DocTransformer.s',
#  'kn8tc_CUNI-Transformer2018.s',
#  'kn8tc_Facebook-AI.s',
#  'kn8tc_Online-A.s',
#  'kn8tc_Online-B.s',
#  'kn8tc_Online-G.s',
#  'kn8tc_Online-W.s',
#  'kn8tc_Online-Y.s',
#  'kn9tc_CUNI-DocTransformer.s',
#  'kn9tc_CUNI-Transformer2018.s',
#  'kn9tc_Facebook-AI.s',
#  'kn9tc_Online-A.s',
#  'kn9tc_Online-B.s',
#  'kn9tc_Online-G.s',
#  'kn9tc_Online-W.s',
#  'kn9tc_Online-Y.s',
#  'na1tc_CUNI-DocTransformer.s',
#  'na1tc_CUNI-Transformer2018.s',
#  'na1tc_Facebook-AI.s',
#  'na1tc_Online-A.s',
#  'na1tc_Online-B.s',
#  'na1tc_Online-G.s',
#  'na1tc_Online-W.s',
#  'na1tc_Online-Y.s',
#  'na2tc_CUNI-DocTransformer.s',
#  'na2tc_CUNI-Transformer2018.s',
#  'na2tc_Facebook-AI.s',
#  'na2tc_Online-A.s',
#  'na2tc_Online-B.s',
#  'na2tc_Online-G.s',
#  'na2tc_Online-W.s',
#  'na2tc_Online-Y.s',
#  'na3tc_CUNI-DocTransformer.s',
#  'na3tc_CUNI-Transformer2018.s',
#  'na3tc_Facebook-AI.s',
#  'na3tc_Online-A.s',
#  'na3tc_Online-B.s',
#  'na3tc_Online-G.s',
#  'na3tc_Online-W.s',
#  'na3tc_Online-Y.s',
#  'na4tc_CUNI-DocTransformer.s',
#  'na4tc_CUNI-Transformer2018.s',
#  'na4tc_Facebook-AI.s',
#  'na4tc_Online-A.s',
#  'na4tc_Online-B.s',
#  'na4tc_Online-G.s',
#  'na4tc_Online-W.s',
#  'na4tc_Online-Y.s',
#  'na5tc_CUNI-DocTransformer.s',
#  'na5tc_CUNI-Transformer2018.s',
#  'na5tc_Facebook-AI.s',
#  'na5tc_Online-A.s',
#  'na5tc_Online-B.s',
#  'na5tc_Online-G.s',
#  'na5tc_Online-W.s',
#  'na5tc_Online-Y.s',
#  'na6tc_CUNI-DocTransformer.s',
#  'na6tc_CUNI-Transformer2018.s',
#  'na6tc_Facebook-AI.s',
#  'na6tc_Online-A.s',
#  'na6tc_Online-B.s',
#  'na6tc_Online-G.s',
#  'na6tc_Online-W.s',
#  'na6tc_Online-Y.s',
#  'na7tc_CUNI-DocTransformer.s',
#  'na7tc_CUNI-Transformer2018.s',
#  'na7tc_Facebook-AI.s',
#  'na7tc_Online-A.s',
#  'na7tc_Online-B.s',
#  'na7tc_Online-G.s',
#  'na7tc_Online-W.s',
#  'na7tc_Online-Y.s',
#  'pn1tc_CUNI-DocTransformer.s',
#  'pn1tc_CUNI-Transformer2018.s',
#  'pn1tc_Facebook-AI.s',
#  'pn1tc_Online-A.s',
#  'pn1tc_Online-B.s',
#  'pn1tc_Online-G.s',
#  'pn1tc_Online-W.s',
#  'pn1tc_Online-Y.s',
#  'pn2tc_CUNI-DocTransformer.s',
#  'pn2tc_CUNI-Transformer2018.s',
#  'pn2tc_Facebook-AI.s',
#  'pn2tc_Online-A.s',
#  'pn2tc_Online-B.s',
#  'pn2tc_Online-G.s',
#  'pn2tc_Online-W.s',
#  'pn2tc_Online-Y.s',
#  'pn3tc_CUNI-DocTransformer.s',
#  'pn3tc_CUNI-Transformer2018.s',
#  'pn3tc_Facebook-AI.s',
#  'pn3tc_Online-A.s',
#  'pn3tc_Online-B.s',
#  'pn3tc_Online-G.s',
#  'pn3tc_Online-W.s',
#  'pn3tc_Online-Y.s',
#  'pn4tc_CUNI-DocTransformer.s',
#  'pn4tc_CUNI-Transformer2018.s',
#  'pn4tc_Facebook-AI.s',
#  'pn4tc_Online-A.s',
#  'pn4tc_Online-B.s',
#  'pn4tc_Online-G.s',
#  'pn4tc_Online-W.s',
#  'pn4tc_Online-Y.s',
#  'pn5tc_CUNI-DocTransformer.s',
#  'pn5tc_CUNI-Transformer2018.s',
#  'pn5tc_Facebook-AI.s',
#  'pn5tc_Online-A.s',
#  'pn5tc_Online-B.s',
#  'pn5tc_Online-G.s',
#  'pn5tc_Online-W.s',
#  'pn5tc_Online-Y.s',
#  'robot_CUNI-DocTransformer.s',
#  'robot_CUNI-Transformer2018.s',
#  'robot_Facebook-AI.s',
#  'robot_Online-A.s',
#  'robot_Online-B.s',
#  'robot_Online-G.s',
#  'robot_Online-W.s',
#  'robot_Online-Y.s',
#  'SLA_CUNI-DocTransformer.s',
#  'SLA_CUNI-Transformer2018.s',
#  'SLA_Facebook-AI.s',
#  'SLA_Online-A.s',
#  'SLA_Online-B.s',
#  'SLA_Online-G.s',
#  'SLA_Online-W.s',
#  'SLA_Online-Y.s',
#  'sublease_CUNI-DocTransformer.s',
#  'sublease_CUNI-Transformer2018.s',
#  'sublease_Facebook-AI.s',
#  'sublease_Online-A.s',
#  'sublease_Online-B.s',
#  'sublease_Online-G.s',
#  'sublease_Online-W.s',
#  'sublease_Online-Y.s']

# %%
bitexts_alg_list
# Out:
# ['Online-W',
#  'Facebook-AI',
#  'Online-Y',
#  'Online-G',
#  'Online-B',
#  'CUNI-Transformer2018',
#  'CUNI-DocTransformer',
#  'Online-A']

# %%
list(bitexts_split['doc'].unique())
# Out:
# ['au1tc',
#  'au2tc',
#  'au3tc',
#  'au4tc',
#  'au5tc',
#  'au6tc',
#  'au7tc',
#  'au8tc',
#  'au9tc',
#  'kn1tc',
#  'kn2tc',
#  'kn3tc',
#  'kn4tc',
#  'kn5tc',
#  'kn6tc',
#  'kn7tc',
#  'kn8tc',
#  'kn9tc',
#  'na1tc',
#  'na2tc',
#  'na3tc',
#  'na4tc',
#  'na5tc',
#  'na6tc',
#  'na7tc',
#  'pn1tc',
#  'pn2tc',
#  'pn3tc',
#  'pn4tc',
#  'pn5tc',
#  'robot',
#  'SLA',
#  'sublease']

# %% [markdown]
# ## 3. Pseudo-Reference Initialization
#
# By this moment, you should have the components for creating the last part of the data: pseudo-reference terms, against which the real translations would be compared. To run that, use the `TermBasedMetricPreparation` class.
#
# As a result, you will have `.csv` files with five columns:
#  - source sentence
#  - translated sentence (tgt_sentence)
#  - source terms
#  - translated "candidate" terms (the translations in each exact sentence)
#  - pseudo-reference terms (the translations that we automatically chose as "correct" ones)
#
#
# Run the whole cycle of preparation with `pipeline` method.

# %%
import os
import nltk
import re
import subprocess

# %%
src1, tgt1, alg1 = 'au1tc_tokenized.txt', 'CUNI-Transformer2018_tokenized.txt', 'au1tc_CUNI-Transformer2018.i'
src2, tgt2, alg2 = 'SLA_tokenized.txt', 'Facebook-AI_tokenized.txt', 'SLA_Facebook-AI.i'

# %%
from metric_preparation import TermBasedMetricPreparator

# %%
tbm = TermBasedMetricPreparator(pseudoref_strategy='first')

# %%
tort_folder = './tort/2022'
input_folder = './tokenized_data/inputs_cs'
output_folder = './tokenized_data/outputs_en_2022'
alignment_folder = './alignments/2022/split_alignments'
for alg in os.listdir(alignment_folder):
    a_path = alignment_folder + '/' + alg
    #print(alg)
    i_fname, o_fname = alg[:-2].split('_')
    i_path = input_folder + '/' + i_fname + '_tokenized.txt'
    o_path = output_folder + '/' + i_fname + '/' + o_fname + '_tokenized.txt'
    try:
        tbm_first = TermBasedMetricPreparator(pseudoref_strategy='first')
        tbm_first.pipeline(i_path, o_path, a_path, tort_folder)
        tbm_frequent = TermBasedMetricPreparator(pseudoref_strategy='frequent')
        tbm_frequent.pipeline(i_path, o_path, a_path, tort_folder)
    except:
        print(alg)

# %%
df = tbm.pipeline(src2, tgt2, alg2, 'alignment_sandbox')#.shape

# %%
df
# Out:
#                                           src_sentence  \
# 0    Smlouva o poskytování služeb podpory provozu a...
# 1    J & T BANKA , a . s . , sídlem Pobřežní 297 / ...
# 2    zapsaná v obchodním rejstříku , který vede Měs...
# 3                          ( dále jen „ Objednatel “ )
# 4                                                    a
# ..                                                 ...
# 855                              J & T BANKA , a . s .
# 856                                      Jméno : [ ● ]
# 857                                      Jméno : [ ● ]
# 858                                     Funkce : [ ● ]
# 859                                     Funkce : [ ● ]
#
#                                       tgt_sentence_str src_terms_str  \
# 0    contract for the provision of services to supp...       Smlouva
# 1    j & amp ; t banka , a . s . , with its registe...
# 2    registered in the commercial register maintain...
# 3        ( hereinafter referred to as the " client " )    Objednatel
# 4                                                  and
# ..                                                 ...           ...
# 855                         j & amp ; t bank , a . s .
# 856                                       name : [ ● ]
# 857                                       name : [ ● ]
# 858                                   function : [ ● ]
# 859                                   function : [ ● ]
#
#     tgt_terms_str gt_terms_str
# 0        contract     contract
# 1
# 2
# 3          client       client
# 4
# ..            ...          ...
# 855
# 856
# 857
# 858
# 859
#
# [860 rows x 5 columns]

# %%
tbm = TermBasedMetric(gt_strategy='frequent')

# %%
df = tbm.pipeline(src2, tgt2, alg2, 'alignment_sandbox')#.shape

# %%
df#.to_csv('df.csv')
# Out:
#                                           src_sentence  \
# 0    Smlouva o poskytování služeb podpory provozu a...
# 1    J & T BANKA , a . s . , sídlem Pobřežní 297 / ...
# 2    zapsaná v obchodním rejstříku , který vede Měs...
# 3                          ( dále jen „ Objednatel “ )
# 4                                                    a
# ..                                                 ...
# 855                              J & T BANKA , a . s .
# 856                                      Jméno : [ ● ]
# 857                                      Jméno : [ ● ]
# 858                                     Funkce : [ ● ]
# 859                                     Funkce : [ ● ]
#
#                                       tgt_sentence_str src_terms_str  \
# 0    contract for the provision of services to supp...       Smlouva
# 1    j & amp ; t banka , a . s . , with its registe...
# 2    registered in the commercial register maintain...
# 3        ( hereinafter referred to as the " client " )    Objednatel
# 4                                                  and
# ..                                                 ...           ...
# 855                         j & amp ; t bank , a . s .
# 856                                       name : [ ● ]
# 857                                       name : [ ● ]
# 858                                   function : [ ● ]
# 859                                   function : [ ● ]
#
#     tgt_terms_str gt_terms_str
# 0        contract       <NONE>
# 1
# 2
# 3          client       client
# 4
# ..            ...          ...
# 855
# 856
# 857
# 858
# 859
#
# [860 rows x 5 columns]

# %%
import pandas as pd 
d = pd.read_csv('Facebook-AI_tokenized.csv', delimiter='\t')

# %%
d
# Out:
#      Unnamed: 0                                       src_sentence  \
# 0             0  Smlouva o poskytování služeb podpory provozu a...
# 1             1  J & T BANKA , a . s . , sídlem Pobřežní 297 / ...
# 2             2  zapsaná v obchodním rejstříku , který vede Měs...
# 3             3                        ( dále jen „ Objednatel “ )
# 4             4                                                  a
# ..          ...                                                ...
# 855         855                              J & T BANKA , a . s .
# 856         856                                      Jméno : [ ● ]
# 857         857                                      Jméno : [ ● ]
# 858         858                                     Funkce : [ ● ]
# 859         859                                     Funkce : [ ● ]
#
#                                       tgt_sentence_str src_terms_str  \
# 0    contract for the provision of services to supp...       Smlouva
# 1    j & amp ; t banka , a . s . , with its registe...           NaN
# 2    registered in the commercial register maintain...           NaN
# 3        ( hereinafter referred to as the " client " )    Objednatel
# 4                                                  and           NaN
# ..                                                 ...           ...
# 855                         j & amp ; t bank , a . s .           NaN
# 856                                       name : [ ● ]           NaN
# 857                                       name : [ ● ]           NaN
# 858                                   function : [ ● ]           NaN
# 859                                   function : [ ● ]           NaN
#
#     tgt_terms_str gt_terms_str
# 0        contract       <NONE>
# 1             NaN          NaN
# 2             NaN          NaN
# 3          client       client
# 4             NaN          NaN
# ..            ...          ...
# 855           NaN          NaN
# 856           NaN          NaN
# 857           NaN          NaN
# 858           NaN          NaN
# 859           NaN          NaN
#
# [860 rows x 6 columns]

# %% [markdown]
# ## 4. Metric Application
#
# Now we can compare the real translation of terms to the pseudo-references. To do that, use `TermBasedMetric` class of the `statistics` module. You should call `make_metrics` method and specify the TORT file. You will obtain two numbers:
#  - termwise metric result (specified as `own` in paper)
#  - overall metric (F1 score) in our case

# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.metrics import f1_score

# %%
from statistics import TermBasedMetric

# %%
tbm = TermBasedMetric(f1_score)

# %%
tbm.make_metrics('./tort/2021/SLA_Online-G_first.csv')
# Out:
# (0.8127823291069866, 0.9224880382775119)

# %%
tbm.make_metrics('./tort/2021/SLA_Online-G_frequent.csv')
# Out:
# (0.8213293376539951, 0.9234449760765551)

# %%
tort_fpath = './tort/2022'
stats_path = './statistics'

# %%
tort_fpath[-4:]
# Out:
# '2022'

# %% [markdown]
# Below, I create the datasets for all metrics for 2021 and 2022 years to compare the rankings of the algorithms between each other and the mainstream metrics (BLEU, chrF, direct assessment)

# %%
version = 'frequent.csv'

docs_list = [file.split('_')[0] for file in os.listdir(tort_fpath)]
algs_list = [file.split('_')[1] for file in os.listdir(tort_fpath)]
#vers_list = [file.split('_')[2] for file in os.listdir(tort_fpath)]

docs_list = list(set(docs_list))
algs_list = list(set(algs_list))
#vers_list = list(set(vers_list))

frequent_own_df = pd.DataFrame(0, index=docs_list, columns=algs_list)
frequent_f1_df = pd.DataFrame(0, index=docs_list, columns=algs_list)

file_list = [file for file in os.listdir(tort_fpath) if file.endswith(version)]
for doc in docs_list:
    for alg in algs_list:
        filename = tort_fpath + '/' + doc + '_' + alg + '_' + version
        own, f1 = tbm.make_metrics(filename)
        frequent_own_df.at[doc, alg] = own
        frequent_f1_df.at[doc, alg] = f1

year = tort_fpath[-4:]
version_for_file = version[:-4]
filename_base = stats_path + '/' + year + '_' + version_for_file + '_'
frequent_own_df.to_csv(filename_base + 'own.csv', sep=';')
frequent_f1_df.to_csv(filename_base + 'f1.csv', sep=';')

# %%
version = 'first.csv'

docs_list = [file.split('_')[0] for file in os.listdir(tort_fpath)]
algs_list = [file.split('_')[1] for file in os.listdir(tort_fpath)]
#vers_list = [file.split('_')[2] for file in os.listdir(tort_fpath)]

docs_list = list(set(docs_list))
algs_list = list(set(algs_list))
#vers_list = list(set(vers_list))

first_own_df = pd.DataFrame(0, index=docs_list, columns=algs_list)
first_f1_df = pd.DataFrame(0, index=docs_list, columns=algs_list)

file_list = [file for file in os.listdir(tort_fpath) if file.endswith(version)]
for doc in docs_list:
    for alg in algs_list:
        filename = tort_fpath + '/' + doc + '_' + alg + '_' + version
        own, f1 = tbm.make_metrics(filename)
        first_own_df.at[doc, alg] = own
        first_f1_df.at[doc, alg] = f1

year = tort_fpath[-4:]
version_for_file = version[:-4]
filename_base = stats_path + '/' + year + '_' + version_for_file + '_'
first_own_df.to_csv(filename_base + 'own.csv', sep=';')
first_f1_df.to_csv(filename_base + 'f1.csv', sep=';')
